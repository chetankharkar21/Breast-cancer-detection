# %%
import pandas as pd
import numpy as np
# Out:
# <ipython-input-1-baf368f80de7>:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pandas as pd

# Load the CSV file, treating the first row as data
df = pd.read_csv('cancer.csv', header=None)

# %%
# Define the column names for columns starting from the 3rd column
column_names = [
    'mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean smoothness', 
    'mean compactness', 'mean concavity', 'mean concave points', 'mean symmetry', 
    'mean fractal dimension', 'radius error', 'texture error', 'perimeter error', 
    'area error', 'smoothness error', 'compactness error', 'concavity error', 
    'concave points error', 'symmetry error', 'fractal dimension error', 'worst radius', 
    'worst texture', 'worst perimeter', 'worst area', 'worst smoothness', 
    'worst compactness', 'worst concavity', 'worst concave points', 'worst symmetry', 
    'worst fractal dimension'
]

# Create a list of default names for the first two columns
default_names = ['column_1', 'column_2']

# Combine default names with the new column names
all_column_names = default_names + column_names

# %%
df.head()
# Out:
#    column_1 column_2  mean radius  mean texture  mean perimeter  mean area  \
# 0    842302        M        17.99         10.38          122.80     1001.0
# 1    842517        M        20.57         17.77          132.90     1326.0
# 2  84300903        M        19.69         21.25          130.00     1203.0
# 3  84348301        M        11.42         20.38           77.58      386.1
# 4  84358402        M        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  worst radius  worst texture  worst perimeter  worst area  \
# ...

# %%
# Define the name of the target column
target_column_name = 'target'

# Create data for the target column. For example, let's add some default values.
# If you have specific target data, replace this with your data.
target_data = [0] * len(df)  # Replace with actual target data if available

# Add the target column to the DataFrame
df[target_column_name] = target_data

# %%
df.head()
# Out:
#    column_1 column_2  mean radius  mean texture  mean perimeter  mean area  \
# 0    842302        M        17.99         10.38          122.80     1001.0
# 1    842517        M        20.57         17.77          132.90     1326.0
# 2  84300903        M        19.69         21.25          130.00     1203.0
# 3  84348301        M        11.42         20.38           77.58      386.1
# 4  84358402        M        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Define the column names (assuming you want to set these before adding the target column)
column_names = [
    'column_1','column_2','mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean smoothness', 
    'mean compactness', 'mean concavity', 'mean concave points', 'mean symmetry', 
    'mean fractal dimension', 'radius error', 'texture error', 'perimeter error', 
    'area error', 'smoothness error', 'compactness error', 'concavity error', 
    'concave points error', 'symmetry error', 'fractal dimension error', 'worst radius', 
    'worst texture', 'worst perimeter', 'worst area', 'worst smoothness', 
    'worst compactness', 'worst concavity', 'worst concave points', 'worst symmetry', 
    'worst fractal dimension', 'target'  # Adding the target column
]

# Update DataFrame columns with these names
df.columns = column_names

# %%
# Add the new target column (initialized to some default value if needed)
df['target'] = df['column_2'].map({'M': 0, 'B': 1})

# Verify the changes
print(df.head())
# Out:
#    column_1 column_2  mean radius  mean texture  mean perimeter  mean area  \
# 0    842302        M        17.99         10.38          122.80     1001.0
# 1    842517        M        20.57         17.77          132.90     1326.0
# 2  84300903        M        19.69         21.25          130.00     1203.0
# 3  84348301        M        11.42         20.38           77.58      386.1
# 4  84358402        M        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.head()
# Out:
#    column_1 column_2  mean radius  mean texture  mean perimeter  mean area  \
# 0    842302        M        17.99         10.38          122.80     1001.0
# 1    842517        M        20.57         17.77          132.90     1326.0
# 2  84300903        M        19.69         21.25          130.00     1203.0
# 3  84348301        M        11.42         20.38           77.58      386.1
# 4  84358402        M        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Drop the first two columns
df = df.drop(df.columns[[0, 1]], axis=1)

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df[df['target'] == 1].shape[0]
# Out:
# 357

# %%
df[df['target'] == 0].shape[0]
# Out:
# 212

# %%
df.shape
# Out:
# (569, 31)

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
# Separate features and target
X = df.drop(columns='target')  # Features
y = df['target']               # Target

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=417)

# %%
# Verify the split
print(f"Training features shape: {X_train.shape}")
print(f"Testing features shape: {X_test.shape}")
print(f"Training target shape: {y_train.shape}")
print(f"Testing target shape: {y_test.shape}")
# Out:
# Training features shape: (483, 30)
# Testing features shape: (86, 30)
# Training target shape: (483,)
# Testing target shape: (86,)

# %%
from sklearn.svm import LinearSVC

# 1. Create an instance of LinearSVC with the specified parameters
model = LinearSVC(dual='auto', penalty='l2', loss='squared_hinge', C=10, random_state=417)


# 2. Fit the model on the training data
model.fit(X_train, y_train)

# Optionally, you can print a confirmation message
print("Model training complete.")
# Out:
# Model training complete.

# %%
# Calculate the accuracy on the test data
test_accuracy = model.score(X_test, y_test)

# Print out the accuracy score
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Test Accuracy: 0.9535

# %%
# 1. Create an instance of LinearSVC with the new parameters
model = LinearSVC(dual='auto', penalty='l2', loss='squared_hinge', C=10, random_state=417, max_iter=3500)

# 2. Fit the model on the training data
model.fit(X_train, y_train)

# Optionally, you can print a confirmation message
print("Model training complete with C=20 and max_iter=3500.")
# Out:
# Model training complete with C=20 and max_iter=3500.

# %%
# Calculate the accuracy on the test data
test_accuracy = model.score(X_test, y_test)

# Print out the accuracy score
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Test Accuracy: 0.9535

# %%
# 1. Calculate the accuracy score on the test data
test_accuracy = model.score(X_test, y_test)

# 2. Print out the accuracy score
print(f"Accuracy on the test set with C=20 and max_iter=3500: {test_accuracy:.4f}")
# Out:
# Accuracy on the test set with C=20 and max_iter=3500: 0.9535

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize and train the LinearSVC model
model = LinearSVC(penalty='l2', loss='squared_hinge', C=10, random_state=417, max_iter=10000)
model.fit(X_train_scaled, y_train)

# Apply PCA to reduce the dataset to 2D for visualization
pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# Predict the labels for the test set
y_pred = model.predict(X_test_scaled)

# Create a mesh grid for plotting the decision boundary
x_min, x_max = X_test_pca[:, 0].min() - 1, X_test_pca[:, 0].max() + 1
y_min, y_max = X_test_pca[:, 1].min() - 1, X_test_pca[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))

# Predict class labels for the mesh grid
Z = model.predict(scaler.inverse_transform(pca.inverse_transform(np.c_[xx.ravel(), yy.ravel()])))
Z = Z.reshape(xx.shape)

# Plot the decision boundary
plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.coolwarm)
plt.scatter(X_test_pca[:, 0], X_test_pca[:, 1], c=y_test, edgecolor='k', cmap=plt.cm.coolwarm)
plt.title('Decision Boundary and Test Data Points')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar()
plt.show()
# Out:
# /lib/python3.12/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
